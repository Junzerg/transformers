# %%
from torch import nn
import numpy as np

# %%
vocab_size = 151671
hidden_size = 1024
padding_idx = 151643

# %%
embed_tokens = nn.Embedding(vocab_size, hidden_size, padding_idx)
embed_tokens
# Out:
# Embedding(151671, 1024, padding_idx=151643)
